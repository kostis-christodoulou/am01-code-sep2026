# %% [markdown]
# # Build an interactive dashboard
#
# We have seen a number of datasets and so far you have analysed and plotted a few things related to, among others,
#
# 1. avocado sales in the United States
# 2. Domestic flights out of the three NYC airports in  2023
#
# Your dashboard should be interactive and allow the user to explore the data in a meaningful way.
#
# You can take your solutions to anything you worked on, and upload it either on claude or chatgpt or qwen or kimi or whatever with a prompt like the one below, if you were to work on an avocado dashboard:
#
# """
# I have a csv file with sales of avocado around the US- avocado.csv. the file has five columns, date (for sales beginning that week), average_price, total_volume, type (conventional and organic), and region (around 50 different regions in the US). I want to create an intractive app/dashboard. can you write me a prompt of the likely layout and functionality? I should be able to find biggest markets and best selling avacado types and prices. I should be able to look at, e.g. evolution or prices by type (organic vs conventional) and by region. Let me know of any other things that would be useful to include. I want to host this on render.com and as it needs to manipualte data, i would like to do it with python and Dash, using a clean, Notion-like UX
#
# REQUIREMENTS:
# - Language/Libraries: Python, pandas (keep all existing analysis logic unchanged),
#   Plotly, and Dash (for the dashboard framework) nad interactivity
# - Do NOT use TypeScript or modify any existing analytical logic — only change how results are visualised
# - Incorporate instructions on how to push the code to github, how to use render.com to read off my github accoint and host it in a free account
#
# BEFORE writing any code:
# 1. Draft an action_plan.md that outlines:
#    - Each section/page of the dashboard and its purpose
#    - Any new interactive elements (dropdowns, sliders, filters) you plan to add and why
#    - The file/component structure you'll use
# 2. Save the plan as action_plan.md and STOP — wait for my approval before writing any code
#
# Only proceed with building after I explicitly confirm the plan.
# """
